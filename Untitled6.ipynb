# %% [markdown]
# <a href="https://colab.research.google.com/github/mokshsutar8-star/Moksh-/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lst = [1, 2, 3, 4, 5]

# Indexing
print(lst[2])      # 3

# Negative indexing
print(lst[-1])     # 5

# Slicing
print(lst[1:4])    # [2, 3, 4]

3
5
[2, 3, 4]

lst = [10, 20, 30, 40]

# Update
lst[1] = 25

# Append
lst.append(50)

# Insert
lst.insert(2, 15)

# Delete
lst.remove(30)

print(lst)

[10, 25, 15, 40, 50]

a = [1, 2, 3]
b = [4, 5]

# Concatenation
c = a + b
print(c)

# Repetition
print(a * 2)

# Length
print(len(c))

# Maximum & Minimum
print(max(c))
print(min(c))
# Out:
# 3
# 5
# [2, 3, 4]
# [10, 25, 15, 40, 50]
# [1, 2, 3, 4, 5]
# [1, 2, 3, 1, 2, 3]
# 5
# 5
# 1
