# %% [markdown]
# <a href="https://colab.research.google.com/github/mokshsutar8-star/Moksh-/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Question 1
a=10
b=5
c = a+b
print(c)

#Question 2
a = 24
print(type(a))
b=3.14
print(type(b))
c="Hello"
print(type(c))
d=True
print(type(d))
e=[1,2,3]
print(type(e))

#Question 3
p=5
q=2.3
r=int(q)
s=str(p)
t=float(p)
u=bool(p)

print(type(r))
print(type(s))
print(type(t))
print(type(u))

#Question 4
x=5
y=10
z=5
print(x>y and x==z)
# Out:
# 15
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'list'>
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>
# False
