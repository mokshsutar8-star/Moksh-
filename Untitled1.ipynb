# %% [markdown]
# <a href="https://colab.research.google.com/github/mokshsutar8-star/Moksh-/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 20
print(type(a))

b = 10.5
print(type(b))

c = "Moksh"
print(type(c))

d = True
print(type(d))

e = [1,2,3]
print(type(e))

f= {"name":"Moksh"}
print(type(f))

g = {"Moksh"}
print(type(g))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'list'>
# <class 'dict'>
# <class 'set'>
