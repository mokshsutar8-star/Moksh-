# %% [markdown]
# <a href="https://colab.research.google.com/github/mokshsutar8-star/Moksh-/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lst = [1, 2, 3, 4, 5]

# Indexing
print(lst[2])      # 3

# Negative indexing
print(lst[-1])     # 5

# Slicing
print(lst[1:4])    # [2, 3, 4]
# Out:
# 3
# 5
# [2, 3, 4]
